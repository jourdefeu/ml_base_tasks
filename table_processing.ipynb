# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df.head(13)
# Out:
#     Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0    20     170         40              2           2002            100
# 1    22     191         43              7           2000            307
# 2    21     172         41              4           2000            186
# 3    19     168         38              2           2003            604
# 4    23     159         36              1           1998            144
# 5    18     177         40              2           2003            100
# 6    18     180         42              0           2004              0
# 7    19     180         48              1           2003              5
# 8    20     185         46              3           2002             28
# 9    22     168         38              6           2000            297
# 10   20     158         35              4           2001           1000
# 11   19     183         44              2           2002             40
# ...

# %%
df.info(13)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df.tail(18)
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 168   22     161         38              7           2000             50
# 169   21     160         37              4           2001            221
# 170   22     168         38              4           2000             49
# 171   20     162         37              2           2002             70
# 172   21     164         37              4           2000            260
# 173   29     176         39              7           1992            233
# 174   20     158         37              3           2001             21
# 175   18     176         38              2           2003            183
# 176   21     162         38              7           2000            150
# 177   23     155         36              6           1999             90
# 178   21     170         39              4           2001            123
# 179   20     176         42              3           2001             80
# ...

# %%
df['Weight'].mean()
# Out:
# 64.03184713375796

# %%
df['Weight'].median()
# Out:
# 60.0

# %%
df['Weight'].min()
# Out:
# 3.0

# %%
df['Weight'].max()
# Out:
# 120.0

# %%
df['Rock paper scissors'].value_counts()
# Out:
# Ножницы    88
# Камень     60
# Бумага     38
# Name: Rock paper scissors, dtype: int64

# %%
df_cut = df[['Weight', 'Sex']]
df_cut.head(11)
# Out:
#     Weight      Sex
# 0     64.0  женский
# 1     73.0  мужской
# 2     60.0  мужской
# 3     59.0  женский
# 4     57.0  женский
# 5     50.0  мужской
# 6     55.0  мужской
# 7    120.0  мужской
# 8     69.0  мужской
# 9     58.0  женский
# 10    47.0  женский

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
gr_w = df[['Weight', 'Growth']]
gr_w[gr_w['Weight']==gr_w['Weight'].max()]
# Out:
#    Weight  Growth
# 7   120.0     180

# %%
df.Army.value_counts()
# Out:
# не призовут (по разным причинам)    149
# могут призвать                       37
# Name: Army, dtype: int64

# %%
army_persons = df[df['Army']=='могут призвать']
free_persons = df[df.Army=='не призовут (по разным причинам)']

# %%
army_persons['Hair length'].mean(), free_persons['Hair length'].mean()
# Out:
# (11.045945945945945, 40.15570469798658)

# %%
army_persons['Hair length'].mean(), free_persons['Hair length'].mean()
# Out:
# (11.045945945945945, 40.15570469798658)

# %%
df[df['Friend number']==0].shape
# Out:
# (2, 48)

# %%
df['Animal'].value_counts()
# Out:
# Кошек                     115
# Собак                      60
# Ненавижу этих животных     11
# Name: Animal, dtype: int64

# %%
df['Floor number'].describe()
# Out:
# count    186.000000
# mean       6.322581
# std        4.338791
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       20.000000
# Name: Floor number, dtype: float64

# %%
dog_lovers = df[df['Animal']=='Собак']
dog_lovers['Floor number'].count()
# Out:
# 60

# %%
dog_lovers[dog_lovers['Floor number']==1]['Floor number'].count()
# Out:
# 7

# %%
round((dog_lovers[dog_lovers['Floor number']==1]['Floor number'].count()) / (dog_lovers['Floor number'].count()) *100)
# Out:
# 12.0

# %%
df['Brother-sister'].value_counts()
# Out:
# есть брат                 62
# есть сестра               55
# нет ни брата ни сестры    39
# есть и брат и сестра      30
# Name: Brother-sister, dtype: int64

# %%
single_child = df[df['Brother-sister']=='нет ни брата ни сестры']
not_single_child = df[df['Brother-sister']!='нет ни брата ни сестры']

# %%
single_child['Social network duration min'].median() - not_single_child['Social network duration min'].median()
# Out:
# 60.0

# %%
df['Fastfood'].value_counts()
# Out:
# KFC                                                82
# Бургер кинг                                        56
# Макдональдс (или как он там сейчас называется?)    48
# Name: Fastfood, dtype: int64

# %%
KFC_persons = df[df['Fastfood']=='KFC']
Burger_persons = df[df['Fastfood']=='Бургер кинг']
Mac_persons = df[df['Fastfood']=='Макдональдс (или как он там сейчас называется?)']

# %%
KFC_persons['Weight'].mean(), Burger_persons['Weight'].mean(), Mac_persons['Weight'].mean()
# Out:
# (66.85915492957747, 64.21739130434783, 58.8)

# %%
KFC_persons['Weight'].mean() - Mac_persons['Weight'].mean()
# Out:
# 8.059154929577474

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df_cut = df[['Year of birth', 'Growth', 'Weight', 'Hair length', 'Shoe size']]

# %%
df_cut_sort = df_cut.sort_values(by=['Shoe size', 'Growth'], ascending=[False, True])

# %%
df_cut_sort.head(9)
# Out:
#      Year of birth  Growth  Weight  Hair length  Shoe size
# 7             2003     180   120.0         20.0         48
# 27            2003     193    61.0          3.0         48
# 8             2002     185    69.0         25.0         46
# 103           2002     197   100.0         23.0         46
# 55            1999     180    92.0          0.2         45
# 76            2002     184     NaN         20.0         45
# 145           1999     184    92.0         45.0         45
# 16            2003     185    64.0          4.0         45
# 20            2001     186    93.0         20.0         45

# %%
df_cut['Full length'] = df_cut['Growth']+df_cut['Hair length']
# Out:
# C:\Users\valer\anaconda3\anac\envs\requirements\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_cut['Full length'].max()
# Out:
# 319.0

# %%
df_cut.corr()
# Out:
#                Year of birth    Growth    Weight  Hair length  Shoe size  \
# Year of birth       1.000000 -0.113357  0.006042     0.095402  -0.108360
# Growth             -0.113357  1.000000  0.544528    -0.554408   0.863252
# Weight              0.006042  0.544528  1.000000    -0.319416   0.591149
# Hair length         0.095402 -0.554408 -0.319416     1.000000  -0.567568
# Shoe size          -0.108360  0.863252  0.591149    -0.567568   1.000000
# Full length         0.064713 -0.235492 -0.145316     0.939398  -0.307190
#
#                Full length
# Year of birth     0.064713
# Growth           -0.235492
# Weight           -0.145316
# Hair length       0.939398
# Shoe size        -0.307190
# Full length       1.000000

# %%
df_group = df.groupby('Glasses')['Russian rating', 'Maths rating'].mean()
# Out:
# C:\Users\valer\anaconda3\anac\envs\requirements\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_group.head()
# Out:
#                                      Russian rating  Maths rating
# Glasses
# да                                        83.388235     56.741176
# нет                                       80.471910     59.955056
# простите. не увидел(а) вопроса ))))       77.900000     54.700000

# %%
df.groupby('Rock paper scissors')['Russian rating', 'Maths rating'].mean().head()
# Out:
# C:\Users\valer\anaconda3\anac\envs\requirements\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      Russian rating  Maths rating
# Rock paper scissors
# Бумага                    76.473684     52.894737
# Камень                    81.450000     62.166667
# Ножницы                   83.988636     57.738636
